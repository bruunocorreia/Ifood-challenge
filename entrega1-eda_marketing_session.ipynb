# %% [markdown]
# ---
# **Turma**: 15
#
# **Grupo**: 11 - Bruno Correia, Gilson Costa, Vivian Liu
#
# **Contato**: `brunovpm@hotmail.com, gilson.costa@gmail.com, liuoliveira.vivian@gmail.com`
#
# **Licença deste notebook**:
# ![CC BY](https://licensebuttons.net/l/by/3.0/88x31.png)
#
# [Clique aqui para saber mais sobre a licença CC BY v4.0](https://creativecommons.org/licenses/by/4.0/legalcode.pt)
#
# ---
# ### Carregando os dados armazendos localmente para serem processados

# %% [markdown]
# Utilize o comando do `dbutils.fs.rm` para remover arquivos e diretórios dentro do DBFS.

# %%
# dbutils.fs.rm('/dbfs/FileStore/ifood/orders', True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
root_dir = '/dbfs/FileStore/ifood'
dbutils.fs.ls(f'{root_dir}')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: [FileInfo(path=&#39;dbfs:/dbfs/FileStore/ifood/customer_segmentation/&#39;, name=&#39;customer_segmentation/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/dbfs/FileStore/ifood/marketing_push_full/&#39;, name=&#39;marketing_push_full/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/dbfs/FileStore/ifood/orders/&#39;, name=&#39;orders/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/dbfs/FileStore/ifood/orders_with_cost_revenue/&#39;, name=&#39;orders_with_cost_revenue/&#39;, size=0),
#  FileInfo(path=&#39;dbfs:/dbfs/FileStore/ifood/sessions_visits/&#39;, name=&#39;sessions_visits/&#39;, size=0)]</div>

# %%
df_marketing_push_full = spark.read.parquet(f'{root_dir}/marketing_push_full')
print((df_marketing_push_full.count(), len(df_marketing_push_full.columns)))

df_sessions_visits = spark.read.parquet(f'{root_dir}/sessions_visits')
print((df_sessions_visits.count(), len(df_sessions_visits.columns)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(28426642, 21)
# (463620, 21)
# </div>

# %%
from pyspark.sql.functions import isnull, when, count, col
import pandas as pd

pd.options.display.precision = 4

def summaryZeroNull(df, lista):
  df_null = df.select([count(when(isnull(c), 1)).alias(c) for c in lista])
  df_zero = df.select([count(when(df[c] == 0, 1)).alias(c) for c in lista])

  final = df_null.union(df_zero)

  dfPandas = final.toPandas()
  
  dfTranspose = dfPandas.transpose(copy=True)
  dfTranspose.reset_index(inplace=True);
  dfTranspose.rename(columns={'index':'summary', 0:'null',1:'zero'}, inplace=True)
  dfTranspose
  
  return dfTranspose
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # marketing_push_full
#
# _26 % de registros duplicados_

# %%
df_marketing_unique = df_marketing_push_full.drop_duplicates()
df_marketing_unique.write.parquet(f'{root_dir}/t11/preprocess/marketing_push_full')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_marketing_push_full = spark.read.parquet(f'{root_dir}/t11/preprocess/marketing_push_full')
print((df_marketing_push_full.count(), len(df_marketing_push_full.columns)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(20875367, 21)
# </div>

# %%
df_marketing_push_full.createOrReplaceTempView("marketing")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # sessions_visits
# _Sem Dados duplicados (463420 registros distintos)_

# %%
df_sessions_visits_unique = df_sessions_visits.drop_duplicates()
df_sessions_visits_unique.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: 463620</div>

# %%
df_sessions_visits.createOrReplaceTempView("session")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Avaliando os bounces de campanhas

# %%
# %sql
SELECT
  user_id,
  campaign_id,
  campaign_name,
  COUNT(*) total
  
FROM marketing

WHERE event_name = 'bounce'
AND campaign_id IS NOT NULL

GROUP BY campaign_id, campaign_name, user_id

HAVING total > 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th
</td><td>2019-07-28 / Android / Almoço - Entrega Grátis</td><td>2</td></tr><tr><td>5ac37268320698605381a7a9</td><td>8cd12196-48e8-4fda-a903-11763ac7c394</td><td>2019-08-10 / iOS / Ativos / Almoço - Light  / CUPOM</td><td>2</td></tr><tr><td>5b3e92f50e560d2b0b0b9e6b</td><td>002a46d8-7cc6-4ca4-a7c6-cf1c1ec3f948</td><td>2019-07-21 / iOS / Almoço / CRM_Restaurante_Expansao (TMA)</td><td>5</td></tr><tr><td>5ac2fc6decfb42ff25006c0c</td><td>c64c6651-a839-4437-a188-ac6399080bdd</td><td>2019-08-29 / IOS / QuintaLoop (New)</td><td>2</td></tr><tr><td>5d0f89b817f4492aebf7079c</td><td>3183fbdc-d2ef-45a6-8dac-b0fec32a6ef3</td><td>2019-07-11 / ANDROID / CRM_Restaurantes_Antigos</td><td>2</td></tr><tr><td>5d05b5173e51337573566e6c</td><td>d61e08bf-1f7c-4555-87bb-43dd4725f18a</td><td>2019-08-02 / iOS / Ativos / Almoço - Light / CUPOM</td><td>3</td></tr><tr><td>5ac36412873c0cfe6f54c3fe</td><td>ddae7034-3811-41c5-ac17-5ea393ea1c61</td><td>2019-09-19 / IOS / Loop (Unaware)</td><td>2</td></tr><tr><td>5c426189ce792d022001564b</td><td>5e571954-8f35-4b38-a962-288307cb8cda</td><td>2019-08-18 / iOS / Ativos / Almoço - Light  / CUPOM</td><td>2</td></tr><tr><td>5cd43a860e47ee538c7f4d37</td><td>7331d850-2160-4d36-a5bf-f1bad004fd71</td><td>2019-06-10 / IOS / Almoço / CUPOM</td><td>2</td></tr><tr><td>5ac36d33832920804d2b37ff</td><td>70286bc4-71bf-4fc4-9c29-b6555f068af4</td><td>2019-09-07 / IOS / Almoço - Super Restaurante</t ...

# %%
# %sql
SELECT *

FROM marketing

WHERE campaign_id = '57cf82b3-88c2-4ffc-bf60-3cf2cb53fc79'
AND user_id = '5ac36b8b0e560d93c57eb758'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_channel</th><th>event_name</th><th>brand</th><th>sample_type</th><th>user_id</th><th>external_user_id</th><th>event_time_utc3</th><th>platform</th><th>campaign_id</th><th>campaign_name</th><th>message_variation_channel</th><th>canvas_name</th><th>canvas_step_id</th><th>canvas_is_first_step</th><th>canvas_first_step_name</th><th>canvas_step_name</th><th>canvas_real_step_name</th><th>canvas_step_index</th><th>canvas_tags</th><th>send_id</th><th>event_date</th></tr></thead><tbody><tr><td>push</td><td>send</td><td>iFood Brasil</td><td>sample</td><td>5ac36b8b0e560d93c57eb758</td><td>87c9e03b3d9b2b792ad457948ae9c2724cee20e3f4170e3283427c1881c8732c</td><td>2019-12-19T09:25:36.000Z</td><td>ios</td><td>57cf82b3-88c2-4ffc-bf60-3cf2cb53fc79</td><td>2019-12-19 / IOS / Almoço / Loop (New Loop)</td><td>ios_push</td><td>null</td><td>null</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>
# %%
# %sql
SELECT DISTINCT user_identifier

FROM session

WHERE user_identifier LIKE '%@%'

# %% [markdown]
# #### Dois registro sem o campaign_name e com campaign_id

# %%
# %sql
SELECT
  * FROM marketing WHERE campaign_name IS Not NULL AND campaign_id = 'dd6faaaa-714c-4a6a-a511-e1259ae74d92' limit 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_channel</th><th>event_name</th><th>brand</th><th>sample_type</th><th>user_id</th><th>external_user_id</th><th>event_time_utc3</th><th>platform</th><th>campaign_id</th><th>campaign_name</th><th>message_variation_channel</th><th>canvas_name</th><th>canvas_step_id</th><th>canvas_is_first_step</th><th>canvas_first_step_name</th><th>canvas_step_name</th><th>canvas_real_step_name</th><th>canvas_step_index</th><th>canvas_tags</th><th>send_id</th><th>event_date</th></tr></thead><tbody><tr><td>push</td><td>received</td><td>iFood Brasil</td><td>sample</td><td>5b7eb90e9ec77b7d9276a422</td><td>e3036be8c90ffef3ddd7e06f85a3192b67e4efffcc85b64fe77f12d3b2f184b1</td><td>2019-07-31T11:21:52.000Z</td><td>android</td><td>dd6faaaa-714c-4a6a-a511-e1259ae74d92</td><td>2019-07-31 / ANDROID / Ativos / Jantar / CUPOM</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2019-07-31T00:00:00.000Z</td></tr></tbody></table></div>

# %%
# %sql
SELECT *
  
FROM marketing
  
WHERE campaign_name IS NULL
AND campaign_id = 'dd6faaaa-714c-4a6a-a511-e1259ae74d92'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_channel</th><th>event_name</th><th>brand</th><th>sample_type</th><th>user_id</th><th>external_user_id</th><th>event_time_utc3</th><th>platform</th><th>campaign_id</th><th>campaign_name</th><th>message_variation_channel</th><th>canvas_name</th><th>canvas_step_id</th><th>canvas_is_first_step</th><th>canvas_first_step_name</th><th>canvas_step_name</th><th>canvas_real_step_name</th><th>canvas_step_index</th><th>canvas_tags</th><th>send_id</th><th>event_date</th></tr></thead><tbody><tr><td>push</td><td>received</td><td>iFood Brasil</td><td>sample</td><td>5ac35d310e560d5d7d1aa9cf</td><td>552756d460425c6ddad686b64ff1898354d7bc34db06765f46a525d6a108c44e</td><td>2019-07-31T11:11:02.000Z</td><td>android</td><td>dd6faaaa-714c-4a6a-a511-e1259ae74d92</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2019-07-31T00:00:00.000Z</td></tr><tr><td>push</td><td>send</td><td>iFood Brasil</td><td>sample</td><td>5ac35d310e560d5d7d1aa9cf</td><td>552756d460425c6ddad686b64ff1898354d7bc34db06765f46a525d6a108c44e</td><td>2019-07-31T11:11:02.000Z</td><td>android</td><td>dd6faaaa-714c-4a6a-a511-e1259ae74d92</td><td>null</td><td>android_push</td><td>null</td><td>null</td><td>0.0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>2019-07-31T00:00:00.000Z</td></tr></tbody></table></div>

# %% [markdown]
# ### Verificar se há mais de um click para a mesma campanha e user

# %%
# %sql
SELECT campaign_id, external_user_id, COUNT(*) total

FROM marketing

WHERE event_name = "click"
AND campaign_id IS NOT NULL

GROUP BY campaign_id, external_user_id

HAVING total > 1

order by total DESC
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
><td>2019-07-08T00:00:00.000+0000</td><td>132606</td></tr><tr><td>2019-07-09T00:00:00.000+0000</td><td>121750</td></tr><tr><td>2019-07-10T00:00:00.000+0000</td><td>129415</td></tr><tr><td>2019-07-11T00:00:00.000+0000</td><td>134009</td></tr><tr><td>2019-07-12T00:00:00.000+0000</td><td>98849</td></tr><tr><td>2019-07-13T00:00:00.000+0000</td><td>106567</td></tr><tr><td>2019-07-14T00:00:00.000+0000</td><td>107316</td></tr><tr><td>2019-07-15T00:00:00.000+0000</td><td>135509</td></tr><tr><td>2019-07-16T00:00:00.000+0000</td><td>190385</td></tr><tr><td>2019-07-17T00:00:00.000+0000</td><td>132885</td></tr><tr><td>2019-07-18T00:00:00.000+0000</td><td>135150</td></tr><tr><td>2019-07-19T00:00:00.000+0000</td><td>114045</td></tr><tr><td>2019-07-20T00:00:00.000+0000</td><td>149660</td></tr><tr><td>2019-07-21T00:00:00.000+0000</td><td>125878</td></tr><tr><td>2019-07-22T00:00:00.000+0000</td><td>118959</td></tr><tr><td>2019-07-23T00:00:00.000+0000</td><td>154091</td></tr><tr><td>2019-07-24T00:00:00.000+0000</td><td>112752</td></tr><tr><td>2019-07-25T00:00:00.000+0000</td><td>120572</td></tr><tr><td>2019-07-26T00:00:00.000+0000</td><td>110627</td></tr><tr><td>2019-07-27T00:00:00.000+0000</td><td>48290</td></tr><tr><td>2019-07-28T00:00:00.000+0000</td><td>129169</td></tr><tr><td>2019-07-29T00:00:00.000+0000</td><td>89247</td></tr><tr><td>2019-07-30T00:00:00.000+0000</td><td>112849</td></tr><tr><td>2019-07-31T00:00:00.000+0000</td><td>114495</td></tr><tr><td>2019-08-01T00:00:00.000+0000</td><td>93818</td></tr><tr><td>2019-08-02T00:00:00.000+0000</td><td>109045</td></tr><tr><td>2019-08-03 ...

# %% [markdown]
# # Eventos por mês

# %%
from pyspark.sql.functions import month, date_format
display(dfEventCast.groupby(date_format('event_date', 'MM - MMM').alias('month')).sum().orderBy('month'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>sum(count)</th></tr></thead><tbody><tr><td>06 - Jun</td><td>2621189</td></tr><tr><td>07 - Jul</td><td>3590220</td></tr><tr><td>08 - Aug</td><td>2303136</td></tr><tr><td>09 - Sep</td><td>2428327</td></tr><tr><td>10 - Oct</td><td>3289334</td></tr><tr><td>11 - Nov</td><td>2989326</td></tr><tr><td>12 - Dec</td><td>3653835</td></tr></tbody></table></div>

# %% [markdown]
# # Envios por dia da semana
# ## Pico de envios
# -  9h (Seg - Sex)
# - 11h (Seg - Dom)
# - 15h (Seg - Sex)
# - 18h (Seg - Dom)
# - 20h (Qui e Dom)
#
# _Quinta possui os cinco pico bem definidos_
#
# _Sábado os dois principais apenas 11h e 18h_
#
# _Domingo três pico 11h, 18h e 20h_

# %%
from pyspark.sql.functions import date_format, dayofweek, hour

display(
  df_marketing_push_full.where('event_name = "send"').groupby(
    dayofweek('event_time_utc3').alias('dow'),
    date_format('event_time_utc3', 'E').alias('day'),
    hour('event_time_utc3').alias('hour')
  ).count().orderBy(['dow', 'hour'])
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
102</td></tr><tr><td>2</td><td>Mon</td><td>20</td><td>67</td></tr><tr><td>2</td><td>Mon</td><td>21</td><td>70</td></tr><tr><td>2</td><td>Mon</td><td>22</td><td>22</td></tr><tr><td>2</td><td>Mon</td><td>23</td><td>4</td></tr><tr><td>3</td><td>Tue</td><td>0</td><td>5</td></tr><tr><td>3</td><td>Tue</td><td>1</td><td>3</td></tr><tr><td>3</td><td>Tue</td><td>2</td><td>1</td></tr><tr><td>3</td><td>Tue</td><td>3</td><td>1</td></tr><tr><td>3</td><td>Tue</td><td>7</td><td>2</td></tr><tr><td>3</td><td>Tue</td><td>8</td><td>12</td></tr><tr><td>3</td><td>Tue</td><td>9</td><td>124</td></tr><tr><td>3</td><td>Tue</td><td>10</td><td>115</td></tr><tr><td>3</td><td>Tue</td><td>11</td><td>673</td></tr><tr><td>3</td><td>Tue</td><td>12</td><td>90</td></tr><tr><td>3</td><td>Tue</td><td>13</td><td>6</td></tr><tr><td>3</td><td>Tue</td><td>14</td><td>3</td></tr><tr><td>3</td><td>Tue</td><td>15</td><td>166</td></tr><tr><td>3</td><td>Tue</td><td>16</td><td>55</td></tr><tr><td>3</td><td>Tue</td><td>17</td><td>67</td></tr><tr><td>3</td><td>Tue</td><td>18</td><td>510</td></tr><tr><td>3</td><td>Tue</td><td>19</td><td>46</td></tr><tr><td>3</td><td>Tue</td><td>20</td><td>66</td></tr><tr><td>3</td><td>Tue</td><td>21</td><td>36</td></tr><tr><td>3</td><td>Tue</td><td>22</td><td>13</td></tr><tr><td>3</td><td>Tue</td><td>23</td><td>6</td></tr><tr><td>4</td><td>Wed</td><td>0</td><td>2</td></tr><tr><td>4</td><td>Wed</td><td>1</td><td>1</td></tr><tr><td>4</td><td>Wed</td><td>3</td><td>1</td></tr><tr><td>4</td><td>Wed</td><td>4</td><td>4</td></tr><tr><td>4</td><td>Wed</td><td>6</td><td>2</td></tr><tr><td>4</td><td>Wed</td><td>7</td><td>2</td></tr><tr><td>4</td><td>Wed</td><td>8</td><td>5</td></tr><tr><td>4</td><td>Wed</td><td>9</td><td>115</td></tr><tr><td>4</td><td>Wed</td><td>10</td><td>6 ...

# %% [markdown]
# # Qualitativas
#
# ### Identificadores
# - user_id
# - external_user_id
# - campaign_id
# - canvas_step_id
# - send_id
#
# ### Categóricas
# - brand
# - event_channel
# - event_name
# - platform
# - sample_type
# - campaign_name
# - message_variation_channel
# - canvas_name
# - canvas_is_first_step
# - canvas_first_step_name
# - canvas_step_name
# - canvas_real_step_name
# - canvas_step_index
# - canvas_tags

# %% [markdown]
# # Valores Nulos
# - 97,06%  canvas_name
# - 97,06%  canvas_step_id
# - 99,93%  canvas_is_first_step
# - 99,93%  canvas_first_step_name
# - 97,06%  canvas_step_name
# - 97,06%  canvas_real_step_name
# - 97,06%  canvas_step_index
# - 99,93%  canvas_tags
# - 100,00% send_id
#
# _Campos não devem ser usados_

# %%
# Função summaryZeroNull definida acima
dfMarketingTranspose = summaryZeroNull(df_marketing_push_full, df_marketing_push_full.columns)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>null</th>
#       <th>zero</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>event_channel</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>event_name</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>brand</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sample_type</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>user_id</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>external_user_id</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>event_time_utc3</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>platform</td>
#       <td>157137</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>campaign_id</td>
#       <td>3074483</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>campaign_name</td>
#       <td>3074485</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>message_variation_channel</td>
#       <td>4277147</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>canvas_name</td>
#       <td>20261286</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>canvas_step_id</td>
#       <td>20262269</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>canvas_is_first_step</td>
#       <td>10038861</td>
#       <td>10821707</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>canvas_first_step_name</td>
#       <td>20860568</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>canvas_step_name</td>
#       <td>20262596</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>canvas_real_step_name</td>
#       <td>20262596</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>canvas_step_index</td>
#       <td>20262596</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>canvas_tags</td>
#       <td>20860568</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>send_id</td>
#       <td>20875367</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>event_date</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
countMarketing = 20875367
dfMarketingTranspose['%null'] = dfMarketingTranspose['null']/countMarketing*100
dfMarketingTranspose['%zero'] = dfMarketingTranspose['zero']/countMarketing*100
dfMarketingTranspose['%final'] = (dfMarketingTranspose['zero'] + dfMarketingTranspose['null'])/countMarketing*100
dfMarketingTranspose
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>null</th>
#       <th>zero</th>
#       <th>%null</th>
#       <th>%zero</th>
#       <th>%final</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>event_channel</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>event_name</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>brand</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sample_type</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>user_id</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>external_user_id</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>event_time_utc3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>platform</td>
#       <td>157137</td>
#       <td>0</td>
#       <td>0.7527</td>
#       <td>0.0000</td>
#       <td>0.7527</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>campaign_id</td>
#       <td>3074483</td>
#       <td>0</td>
#       <td>14.7278</td>
#       <td>0.0000</td>
#       <td>14.7278</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>campaign_name</td>
#       <td>3074485</td>
#       <td>0</td>
#       <td>14.7278</td>
#       <td>0.0000</td>
#       <td>14.7278</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>message_variation_channel</td>
#       <td>4277147</td>
#       <td>0</td>
#       <td>20.4890</td>
#       <td>0.0000</td>
#       <td>20.4890</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>canvas_name</td>
#       <td>20261286</td>
#       <td>0</td>
#       <td>97.0583</td>
#       <td>0.0000</td>
#       <td>97.0583</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>canvas_step_id</td>
#       <td>20262269</td>
#       <td>0</td>
#       <td>97.0631</td>
#       <td>0.0000</td>
#       <td>97.0631</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>canvas_is_first_step</td>
#       <td>10038861</td>
#       <td>10821707</td>
#       <td>48.0895</td>
#       <td>51.8396</td>
#       <td>99.9291</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>canvas_first_step_name</td>
#       <td>20860568</td>
#       <td>0</td>
#       <td>99.9291</td>
#       <td>0.0000</td>
#       <td>99.9291</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>canvas_step_name</td>
#       <td>20262596</td>
#       <td>0</td>
#       <td>97.0646</td>
#       <td>0.0000</td>
#       <td>97.0646</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>canvas_real_step_name</td>
#       <td>20262596</td>
#       <td>0</td>
#       <td>97.0646</td>
#       <td>0.0000</td>
#       <td>97.0646</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>canvas_step_index</td>
#       <td>20262596</td>
#       <td>0</td>
#       <td>97.0646</td>
#       <td>0.0000</td>
#       <td>97.0646</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>canvas_tags</td>
#       <td>20860568</td>
#       <td>0</td>
#       <td>99.9291</td>
#       <td>0.0000</td>
#       <td>99.9291</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>send_id</td>
#       <td>20875367</td>
#       <td>0</td>
#       <td>100.0000</td>
#       <td>0.0000</td>
#       <td>100.0000</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>event_date</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#       <td>0.0000</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Campo: brand
# _100% do valores "iFood Brasil"_
#
# _Campo deve ser descartado_

# %%
df_marketing_push_full.where('brand <> "iFood Brasil"').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: 0</div>

# %% [markdown]
# # Campo: event_channel
# _100 % dos valores "push"_
#
# _Campo deve ser descartado_

# %%
df_marketing_push_full.where('event_channel <> "push"').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[246]: 0</div>

# %% [markdown]
# # Campo: event_name
# _send, received, click, bounce_
#
# _Fluxo de estado provável : send -> received -> [click ou bounce]_

# %%
display(
  df_marketing_push_full.groupby(
    'event_name'
  ).count().orderBy('count', ascending=False)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_name</th><th>count</th></tr></thead><tbody><tr><td>send</td><td>10356003</td></tr><tr><td>received</td><td>10182463</td></tr><tr><td>click</td><td>322629</td></tr><tr><td>bounce</td><td>14272</td></tr></tbody></table></div>

# %%
display(
  df_marketing_push_full.where(
    'event_name IN("click", "bounce")'
  ).groupby(
    'event_name'
  ).count().orderBy('count', ascending=False)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>event_name</th><th>count</th></tr></thead><tbody><tr><td>click</td><td>322629</td></tr><tr><td>bounce</td><td>14272</td></tr></tbody></table></div>

# %%
dbClick = df_marketing_push_full.where('event_name = "click"').head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# *Busca de um evento de click para análise*

# %%
pdClick = pd.DataFrame(dbClick)
pdClick.columns = df_marketing_push_full.columns
pdClick.astype(
  {
    'event_time_utc3':'datetime64[ns]',
    'event_date':'datetime64[ns]',
  }
).transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>event_channel</th>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#     </tr>
#     <tr>
#       <th>event_name</th>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#       <td>click</td>
#     </tr>
#     <tr>
#       <th>brand</th>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#     </tr>
#     <tr>
#       <th>sample_type</th>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#     </tr>
#     <tr>
#       <th>user_id</th>
#       <td>5d095eee9799566ab68b676f</td>
#       <td>5ac3817a9e1aaa93cdce4750</td>
#       <td>5ac37f7d55406de396f0e28a</td>
#       <td>5c6761a5392abb857b7b8945</td>
#       <td>5bca8d7b510a69c98efc2638</td>
#       <td>5ac2ff1c0b1e36d071e043db</td>
#       <td>5bf8835ba9c41dd9be27d4ac</td>
#       <td>5aedd714f26e04fbaef7127b</td>
#       <td>5ac2f4644d6e451c464254c3</td>
#       <td>5b02eb0c320698abd033a163</td>
#     </tr>
#     <tr>
#       <th>external_user_id</th>
th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_is_first_step</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>canvas_first_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_real_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_index</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_tags</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>send_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>event_date</th>
#       <td>2019-10-16 00:00:00</td>
#       <td>2019-10-02 00:00:00</td>
#       <td>2019-11-15 00:00:00</td>
#       <td>2019-07-28 00:00:00</td>
#       <td>2019-11-26 00:00:00</td>
#       <td>2019-11-20 00:00:00</td>
#       <td>2019-07-30 00:00:00</td>
#       <td>2019-11-12 00:00:00</td>
#       <td>2019-06-02 00:00:00</td>
#       <td>2019-11-22 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# *Cliente de um click para análise*

# %%
dbCliente = df_marketing_push_full.where(
  "user_id = '5ac387e559e5ad7ee62471c3' and event_date = '2019-09-29T00:00:00.000Z' and campaign_id = '903fe138-592c-461c-be4d-1c1f596af223'"
).orderBy(
  'campaign_name'
).toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdCliente = dbCliente
pdCliente.columns = df_marketing_push_full.columns
pdCliente.drop(
  columns=['user_id', 'external_user_id']
).astype(
  {
    'event_date': 'datetime64[ns]',
    'event_time_utc3': 'datetime64[ns]'
  }
).sort_values('event_time_utc3', ascending=False).transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>2</th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>event_channel</th>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#     </tr>
#     <tr>
#       <th>event_name</th>
#       <td>click</td>
#       <td>send</td>
#       <td>received</td>
#     </tr>
#     <tr>
#       <th>brand</th>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#     </tr>
#     <tr>
#       <th>sample_type</th>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#     </tr>
#     <tr>
#       <th>event_time_utc3</th>
#       <td>2019-09-29 20:55:53</td>
#       <td>2019-09-29 20:55:41</td>
#       <td>2019-09-29 20:55:41</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>ios</td>
#       <td>ios</td>
#       <td>ios</td>
#     </tr>
#     <tr>
#       <th>campaign_id</th>
#       <td>903fe138-592c-461c-be4d-1c1f596af223</td>
#       <td>903fe138-592c-461c-be4d-1c1f596af223</td>
#       <td>903fe138-592c-461c-be4d-1c1f596af223</td>
#     </tr>
#     <tr>
#       <th>campaign_name</th>
#       <td>2019-09-29 / iOS / Ativos / Ceia - KA / CUPOM</td>
#       <td>2019-09-29 / iOS / Ativos / Ceia - KA / CUPOM</td>
#       <td>2019-09-29 / iOS / Ativos / Ceia - KA / CUPOM</td>
#     </tr>
#     <tr>
#       <th>message_variation_channel</th>
#       <td>ios_push</td>
#       <td>ios_push</td>
#       <td>ios_push</td>
#     </tr>
#     <tr>
#       <th>canvas_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_is_first_step</th>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>canvas_first_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_real_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_index</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>canvas_tags</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>send_id</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>event_date</th>
#       <td>2019-09-29 00:00:00</td>
#       <td>2019-09-29 00:00:00</td>
#       <td>2019-09-29 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Há mais clicks nos push de campanhas ?
#
# _Avaliar se podemos analisar apenas os dados de campanhas_

# %%
# %sql
SELECT
if(campaign_id is null, "Sem Campanha", "Com Campanha") AS Campanha, COUNT(*) total

FROM marketing

WHERE event_name = 'click'

GROUP BY 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Campanha</th><th>total</th></tr></thead><tbody><tr><td>Sem Campanha</td><td>46978</td></tr><tr><td>Com Campanha</td><td>275651</td></tr></tbody></table></div>

# %%
pd.DataFrame(df_marketing_push_full.dtypes)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>event_channel</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>event_name</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>brand</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sample_type</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>user_id</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>external_user_id</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>event_time_utc3</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>platform</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>campaign_id</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>campaign_name</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>message_variation_channel</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>canvas_name</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>canvas_step_id</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>canvas_is_first_step</td>
#       <td>double</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>canvas_first_step_name</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>canvas_step_name</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>canvas_real_step_name</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>canvas_step_index</td>
#       <td>double</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>canvas_tags</td>
#       <td>string</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>send_id</td>
#       <td>double</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>event_date</td>
#       <td>string</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dfMarketingPandas = pd.DataFrame(df_marketing_push_full.head(5))
dfMarketingPandas.columns = df_marketing_push_full.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfMarketingPandas.transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>event_channel</th>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#     </tr>
#     <tr>
#       <th>event_name</th>
#       <td>received</td>
#       <td>send</td>
#       <td>send</td>
#       <td>received</td>
#       <td>send</td>
#     </tr>
#     <tr>
#       <th>brand</th>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#     </tr>
#     <tr>
#       <th>sample_type</th>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#     </tr>
#     <tr>
#       <th>user_id</th>
#       <td>5ac365c96ee329b1951ac7e9</td>
#       <td>5ac3121c8e5b4b5696ac49dc</td>
#       <td>5ac2c99c059e9ee7e5eed43b</td>
#       <td>5ac36acd409f7734a97df5b9</td>
#       <td>5ac3654ad75e5a3c29fb256f</td>
#     </tr>
#     <tr>
#       <th>external_user_id</th>
#       <td>6f040026ecb33d63875ca8340a55db433fe185d8e40a01...</td>
#       <td>290070089ba4bc832a39ffdb7f3bc7e70cb4e7746bc511...</td>
#       <td>0753a6e30f7b58265e00becd06423d17181aa22d43f51e...</td>
#       <td>8468bb60ea7888a33a3506e4f3d2b541afca6651bde242...</td>
#       <td>6cbda064947aec380ac7c459de0902fc0182b23dcbaa59...</td>
#     </tr>
#     <tr>
#       <th>event_time_utc3</th>
#       <td>2019-08-29T18:31:10.000Z</td>
#       <td>2019-11-13T12:38:00.000Z</td>
#       <td>2019-10-10T11:31:02.000Z</td>
#       <td>2019-10-27T21:05:31.000Z</td>
#       <td>2019-10-28T11:30:49.000Z</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>android</td>
#       <td>ios</td>
#       <td>ios</td>
#       <td>android</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>campaign_id</th>
#       <td>23e2e9bf-61ae-48aa-8e24-85d8f2348b21</td>
#       <td>None</td>
#       <td>c3858a3b-1eea-4ab8-99ca-5b0166a9fb14</td>
#       <td>e5b7abaf-eafa-4a2e-bde5-62965fefa0f5</td>
#       <td>2398c143-4f12-4541-afd9-06bb94cb7b8a</td>
#     </tr>
#     <tr>
#       <th>campaign_name</th>
#       <td>2019-08-29 / ANDROID / 20190829MIDIAKITKAS</td>
#       <td>None</td>
#       <td>2019-10-10 / IOS / Almoço / Cidades DFN Geral</td>
#       <td>2019-10-27 / ANDROID / Ativos / Ceia - KA / CUPOM</td>
#       <td>2019-10-28 / ANDROID / Ativos / Almoço - Light...</td>
#     </tr>
#     <tr>
#       <th>message_variation_channel</th>
#       <td>android_push</td>
#       <td>None</td>
#       <td>ios_push</td>
#       <td>android_push</td>
#       <td>android_push</td>
#     </tr>
#     <tr>
#       <th>canvas_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_is_first_step</th>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>canvas_first_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_real_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_index</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_tags</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>send_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>event_date</th>
#       <td>2019-08-29T00:00:00.000Z</td>
#       <td>2019-11-13T00:00:00.000Z</td>
#       <td>2019-10-10T00:00:00.000Z</td>
#       <td>2019-10-28T00:00:00.000Z</td>
#       <td>2019-10-28T00:00:00.000Z</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dbBounce = df_marketing_push_full.where('event_name = "bounce"').head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdBounce = pd.DataFrame(dbBounce)
pdBounce.columns = df_marketing_push_full.columns
pdBounce.astype(
  {
    'event_time_utc3':'datetime64[ns]',
    'event_date':'datetime64[ns]',
  }
).transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>event_channel</th>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#     </tr>
#     <tr>
#       <th>event_name</th>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#       <td>bounce</td>
#     </tr>
#     <tr>
#       <th>brand</th>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#     </tr>
#     <tr>
#       <th>sample_type</th>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>2019-07-18 / ANDROID / CRM_Restaurantes_Expans...</td>
#       <td>2019-10-01 / ANDROID / Almoço / To Go</td>
#       <td>2019-08-07 / ANDROID / Ativos / Lanche da Tard...</td>
#       <td>2019-09-28 / ANDROID / Jantar / Ativos Campinas</td>
#       <td>2019-10-13 / iOS / Ativos / Almoço - Light / C...</td>
#       <td>2019-08-14 / ANDROID / Almoço - Light  / CUPOM</td>
#       <td>2019-09-12 / ANDROID / Ativos / Almoço - Light...</td>
#     </tr>
#     <tr>
#       <th>message_variation_channel</th>
#       <td>None</td>
#       <td>ios_push</td>
#       <td>android_push</td>
#       <td>None</td>
#       <td>android_push</td>
#       <td>android_push</td>
#       <td>android_push</td>
#       <td>ios_push</td>
#       <td>android_push</td>
#       <td>android_push</td>
#     </tr>
#     <tr>
#       <th>canvas_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_is_first_step</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>canvas_first_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_real_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_index</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_tags</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>send_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>event_date</th>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-11-05 00:00:00</td>
#       <td>2019-06-29 00:00:00</td>
#       <td>2019-07-18 00:00:00</td>
#       <td>2019-10-01 00:00:00</td>
#       <td>2019-08-07 00:00:00</td>
#       <td>2019-09-28 00:00:00</td>
#       <td>2019-10-13 00:00:00</td>
#       <td>2019-08-14 00:00:00</td>
#       <td>2019-09-12 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
dbClienteBounce = df_marketing_push_full.where("user_id = '5ac35888752e2a98422f4ee1' and event_date = '2019-10-23T00:00:00.000Z'").orderBy('campaign_name').toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdClienteBounce = dbClienteBounce.copy()
pdClienteBounce.columns = df_marketing_push_full.columns
pdClienteBounce.drop(
  columns=['user_id', 'external_user_id']
).astype(
  {
    'event_date': 'datetime64[ns]',
    'event_time_utc3': 'datetime64[ns]'
  }
).sort_values('event_time_utc3', ascending=False).transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>3</th>
#       <th>4</th>
#       <th>6</th>
#       <th>8</th>
#       <th>2</th>
#       <th>12</th>
#       <th>5</th>
#       <th>11</th>
#       <th>0</th>
#       <th>1</th>
#       <th>7</th>
#       <th>9</th>
#       <th>10</th>
#       <th>13</th>
#       <th>14</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>event_channel</th>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#       <td>push</td>
#     </tr>
#     <tr>
#       <th>event_name</th>
#       <td>received</td>
#       <td>send</td>
#       <td>received</td>
#       <td>send</td>
#       <td>received</td>
#       <td>send</td>
#       <td>received</td>
#       <td>send</td>
#       <td>bounce</td>
#       <td>send</td>
#       <td>received</td>
#       <td>received</td>
#       <td>received</td>
#       <td>send</td>
#       <td>send</td>
#     </tr>
#     <tr>
#       <th>brand</th>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#       <td>iFood Brasil</td>
#     </tr>
#     <tr>
#       <th>sample_type</th>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#       <td>sample</td>
#     </tr>
#     <tr>
#       <th>event_time_utc3</th>
#       <td>2019-10-23 19:06:36</td>
#       <td>2019-10-23 19:06:36</td>
#       <td>2019-10-23 19:06:36</td>
#       <td>2019-10-23 19:06:36</td>
#       <td>2019-10-23 11:41:35</td>
#       <td>2019-10-23 11:41:35</td>
#       <td>2019-10-23 11:41:34</td>
#       <td>2019-10-23 11:41:34</td>
#       <td>2019-10-23 11:16:21</td>
#       <td>2019-10-23 11:16:21</td>
#       <td>2019-10-23 11:16:21</td>
#       <td>2019-10-23 11:16:21</td>
#       <td>2019-10-23 11:16:21</td>
#       <td>2019-10-23 11:16:21</td>
#       <td>2019-10-23 11:16:21</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#       <td>android</td>
#     </tr>
#     <tr>
#       <th>campaign_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>campaign_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>message_variation_channel</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_id</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_is_first_step</th>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>canvas_first_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_real_step_name</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>canvas_step_index</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>canvas_tags</th>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>send_id</th>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>event_date</th>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#       <td>2019-10-23 00:00:00</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Campo: platform
# _157137 valores nulos_

# %%
display(df_marketing_push_full.groupby('platform').count().orderBy('count', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>platform</th><th>count</th></tr></thead><tbody><tr><td>android</td><td>12693963</td></tr><tr><td>ios</td><td>8024267</td></tr><tr><td>null</td><td>157137</td></tr></tbody></table></div>

# %% [markdown]
# # Campo: message_variation_channel
# _4277147 valores nulos_
#
# _Parece bastante correlacionado com o campo de plataforma_
#
# _Usar campo para preencher 111033 valores nulos do campo platform_

# %%
display(df_marketing_push_full.groupby('message_variation_channel').count().orderBy('count', ascending=False))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>message_variation_channel</th><th>count</th></tr></thead><tbody><tr><td>android_push</td><td>10218745</td></tr><tr><td>ios_push</td><td>6379475</td></tr><tr><td>null</td><td>4277147</td></tr></tbody></table></div>

# %%
display(
  df_marketing_push_full.groupby(
    'platform', 'message_variation_channel'
  ).count().orderBy('count', ascending=False)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>platform</th><th>message_variation_channel</th><th>count</th></tr></thead><tbody><tr><td>android</td><td>android_push</td><td>10154789</td></tr><tr><td>ios</td><td>ios_push</td><td>6332398</td></tr><tr><td>android</td><td>null</td><td>2539174</td></tr><tr><td>ios</td><td>null</td><td>1691869</td></tr><tr><td>null</td><td>android_push</td><td>63956</td></tr><tr><td>null</td><td>ios_push</td><td>47077</td></tr><tr><td>null</td><td>null</td><td>46104</td></tr></tbody></table></div>

# %% [markdown]
# # Campo: sample_type
# _control e sample_
#
# _relativamente pouco registros para o valor control_
#
# _provavelmente usado para acompanhamento de campanhas especificas_

# %%
display(df_marketing_push_full.groupby('sample_type').count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>sample_type</th><th>count</th></tr></thead><tbody><tr><td>control</td><td>157137</td></tr><tr><td>sample</td><td>20718230</td></tr></tbody></table></div>

# %%
pdControl = pd.DataFrame(
  df_marketing_push_full.where(
    'sample_type = "control"'
  ).groupby(
    'campaign_id'
  ).count().collect()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdControl.columns = ['campaign_id', 'count']
pdControl.sort_values('campaign_id')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>campaign_id</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>151</th>
#       <td>00048e73-07ff-40da-a95b-6d226d82c230</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1790</th>
#       <td>004e5b1d-aea7-4829-b053-ac2d3c2ca1b5</td>
#       <td>179</td>
#     </tr>
#     <tr>
#       <th>2266</th>
#       <td>004f627a-ee2f-4f37-b828-6a1019c6ccc6</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>2198</th>
#       <td>00e57dca-4284-4796-9b61-99e2a8992a3f</td>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>1482</th>
#       <td>00ec5f6a-f10e-474e-89e9-e84fc24f3226</td>
#       <td>62</td>
#     </tr>
#     <tr>
#       <th>1281</th>
#       <td>00f76027-c8ad-433c-8ce2-fad26ab11640</td>
#       <td>243</td>
#     </tr>
#     <tr>
#       <th>1815</th>
#       <td>01091e62-7502-47b5-a66b-8c186f295378</td>
#       <td>66</td>
#     </tr>
#     <tr>
#       <th>1625</th>
#       <td>0113d45a-3176-4062-ad97-ed0e3acf29c3</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>725</th>
#       <td>0140bac9-ba0d-45ea-917a-05ed0de5ad5a</td>
#       <td>86</td>
#     </tr>
#     <tr>
#       <th>1487</th>
#       <td>0182f0ba-4494-49c8-97a8-ff8a40389946</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>1241</th>
#       <td>019aa3d7-1e5b-4d05-b4e9-7f1426d22bfd</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>302</th>
#       <td>019ec1e2-1bb2-442f-a263-af6d7f3f71d9</td>
#       <td>80</td>
#     </tr>
#     <tr>
#       <th>555</th>
#       <td>01b36c4c-2588-47db-a8c4-92805fc40267</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1032</th>
#       <td>01b56b76-0d3d-45e2-8fce-bbdaa8382f07</td>
#       <td>297</td>
#     </tr>
#     <tr>
#       <th>619</th>
#       <td>01e070b3-7ffe-43f9-bb0b-d783382219a7</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th
td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>174</th>
#       <td>ff1ca24c-74ea-4400-84d4-e0235c983aca</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>414</th>
#       <td>ff21a721-b035-4d03-813e-3bacedbc16b7</td>
#       <td>112</td>
#     </tr>
#     <tr>
#       <th>2229</th>
#       <td>ff23a569-1319-4444-b3df-522ff29d3416</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>1246</th>
#       <td>ff413985-425c-4328-98f1-2aa3c8ec4a3a</td>
#       <td>31</td>
#     </tr>
#     <tr>
#       <th>1918</th>
#       <td>ff4b6478-3a53-4598-8f56-ea87ad0c53e4</td>
#       <td>22</td>
#     </tr>
#     <tr>
#       <th>2133</th>
#       <td>ff521e18-3746-4629-87ba-12d8ce2dcb67</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>141</th>
#       <td>ff5b0c60-b15b-42ef-97ab-4ea42c810ba7</td>
#       <td>188</td>
#     </tr>
#     <tr>
#       <th>147</th>
#       <td>ff84f9e1-af30-434f-8bc8-df7d66ca3a2e</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>811</th>
#       <td>ff99c98e-ffdc-4eb6-8256-9f693d6084ac</td>
#       <td>45</td>
#     </tr>
#     <tr>
#       <th>1000</th>
#       <td>ffce9aa0-a465-40b7-bf53-280b037a1e35</td>
#       <td>61</td>
#     </tr>
#     <tr>
#       <th>638</th>
#       <td>fff0a0c0-8ca2-42b6-8655-e2164366a409</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>485</th>
#       <td>None</td>
#       <td>988</td>
#     </tr>
#   </tbody>
# </table>
# <p>2326 rows × 2 columns</p>
# </div>

# %% [markdown]
# # Campo: campaign_name
# _3074485 registros nulos (14,73%)_
#
# _talvez usar o campos para extrair informações de cupons, desconto e refeição relacionada ao push_

# %%
df_marketing_push_full.where('campaign_name is not null').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: 17800882</div>

# %%
dbCampaignName = df_marketing_push_full.select('campaign_name').distinct()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdCampaignName = pd.DataFrame(dbCampaignName.collect())
pdCampaignName.columns = ['name']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'\d\d\d\d-\d\d-\d\d', '')
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'\d\d\d\d\d\d\d\d', '')
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'^\s*\/\s*', '')
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'^\s*-\s*', '')
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'^ANDROID\s*\/\s*', '')
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'^Android\s*\/\s*', '')
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'^iOS\s*\/\s*', '')
pdCampaignName['name'] = pdCampaignName['name'].str.replace(r'^IOS\s*\/\s*', '')
pdCampaignName['total'] = 1
resultado = pd.DataFrame(pdCampaignName.groupby('name').sum())
resultado = resultado.reset_index()
display(spark.createDataFrame(resultado))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>name</th><th>total</th></tr></thead><tbody><tr><td>1RECCUPOM70OFF</td><td>4</td></tr><tr><td>2RECCUPOMDIADOSNAMOS</td><td>2</td></tr><tr><td>5RECCUPOM70OFF</td><td>2</td></tr><tr><td>70% OFF</td><td>9</td></tr><tr><td>9RECCUPOM70OFF</td><td>2</td></tr><tr><td>ACAOPONTUALCES</td><td>4</td></tr><tr><td>ACAOPONTUALKA</td><td>4</td></tr><tr><td>ACAOPONTUALKAS</td><td>8</td></tr><tr><td>ALMOCO / RECSPROMOBOMB_HBB_RGZ_11h00_novos</td><td>1</
td><td>2</td></tr><tr><td>Almoço / ESTEIRAKA</td><td>2</td></tr><tr><td>Almoço / ESTEIRAKA / CUPOM</td><td>2</td></tr><tr><td>Almoço / Em Ativação Campinas</td><td>2</td></tr><tr><td>Almoço / Gourmet</td><td>6</td></tr><tr><td>Almoço / Instalação Campinas</td><td>4</td></tr><tr><td>Almoço / Lancha / CUPOM</td><td>10</td></tr><tr><td>Almoço / Lancha / CUPOM (multiplo R$10)</td><td>25</td></tr><tr><td>Almoço / Lancha / CUPOM (unico R$10)</td><td>2</td></tr><tr><td>Almoço / Lancha / CUPOM (unico R$15)</td><td>4</td></tr><tr><td>Almoço / Lancha / CUPOM (único R$15)</td><td>2</td></tr><tr><td>Almoço / Lancha / CUPOM 15 dias</td><td>2</td></tr><tr><td>Almoço / Lancha BH / Ativos</td><td>8</td></tr><tr><td>Almoço / Lancha BH / CUPOM</td><td>4</td></tr><tr><td>Almoço / Lancha BH / CUPOM_Churn</td><td>4</td></tr><tr><td>Almoço / Lancha BH / Cupom_Lembrete_20</td><td>2</td></tr ...

# %% [markdown]
# # Campo: Segmentação de click por campanha de cupom

# %%
import re 

def filterCampaignName(name):
  if name == None:
    return None
  
  name = re.sub(r'\d\d\d\d-\d\d-\d\d', '', name)
  name = re.sub(r'\d\d\d\d\d\d\d\d', '', name)
  name = re.sub(r'^\s*\/\s*', '', name)
  name = re.sub(r'^\s*-\s*', '', name)
  name = re.sub(r'^ANDROID\s*\/\s*', '', name, flags=re.IGNORECASE)
  name = re.sub(r'^iOS\s*\/\s*', '', name, flags=re.IGNORECASE)
  
  return name

filterCampaignName('2019-04-16 / IOS / Almoço / CUPOM')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: &#39;Almoço / CUPOM&#39;</div>

# %%
from pyspark.sql.functions import col, when

df_marketing_push_full.createOrReplaceTempView("cupom_click")

# campaignClick = spark.sql(
#   'SELECT lower(campaign_name) like "%cupom%" cupom,  lower(campaign_name) like "%voucher%" voucher, count(*) total from cupom_click where event_name = "click" group by cupom, voucher'
# )
campaignClick = spark.sql(
   'SELECT campaign_name, count(*) total, sum(if(event_name = "send", 1, 0)) send, sum(if(event_name = "received", 1, 0)) received, sum(if(event_name = "bounce", 1, 0)) bounce, sum(if(event_name = "click", 1, 0)) click from cupom_click group by campaign_name order by click / total desc'
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdCampaignClick = campaignClick.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pdCampaignClick['campaign_name'] = pdCampaignClick['campaign_name'].apply(filterCampaignName)
pdCampaignClickGroup = pdCampaignClick.groupby('campaign_name').sum()
pdCampaignClickGroup = pdCampaignClickGroup.reset_index()
pdCampaignClickGroup
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>campaign_name</th>
#       <th>total</th>
#       <th>send</th>
#       <th>received</th>
#       <th>bounce</th>
#       <th>click</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1RECCUPOM70OFF</td>
#       <td>1798</td>
#       <td>879</td>
#       <td>829</td>
#       <td>2</td>
#       <td>88</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2RECCUPOMDIADOSNAMOS</td>
#       <td>4813</td>
#       <td>2418</td>
#       <td>2273</td>
#       <td>1</td>
#       <td>121</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5RECCUPOM70OFF</td>
#       <td>1825</td>
#       <td>908</td>
#       <td>843</td>
#       <td>4</td>
#       <td>70</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td
td><td>1</td><td>0</td><td>0</td><td>0</td><td>1</td></tr><tr><td>Almoço - Teste AB (Cupom de R$8) / CUPOM</td><td>3</td><td>0</td><td>0</td><td>0</td><td>3</td></tr><tr><td>Almoço - inativos / CUPOM</td><td>2</td><td>0</td><td>0</td><td>0</td><td>2</td></tr><tr><td>Almoço / 70% OFF</td><td>1957</td><td>966</td><td>954</td><td>3</td><td>34</td></tr><tr><td>Almoço / Ativos Campinas</td><td>2753</td><td>1373</td><td>1348</td><td>0</td><td>32</td></tr><tr><td>Almoço / Ativos C ...

# %% [markdown]
# # Evento de click

# %%
dbTotalClick = df_marketing_push_full.where('event_name = "click"')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(dbTotalClick.groupby('platform').count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>platform</th><th>count</th></tr></thead><tbody><tr><td>android</td><td>238947</td></tr><tr><td>ios</td><td>83682</td></tr></tbody></table></div>

# %% [markdown]
# # Tabela : sessions_visits

# %%
df_sessions_visits = spark.read.parquet(f'{root_dir}/sessions_visits')
print((df_sessions_visits.count(), len(df_sessions_visits.columns)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">(463620, 21)
# </div>

# %% [markdown]
# # Variáveis Qualitativas
#
# ### Identificadores
#
# - session_id
# - dau
# - user_identifier
# - user_account_uuid
#
# ### Categóricas
#
# - platform
# - device_model
# - device_manufacturer
# - media_network
# - first_order_origin_feature

# %% [markdown]
# # Campo: platform
# _Duas opções balanceadas (Android x IOS)_

# %%
# duas opções balanceadas (Android x IOS)
display(df_sessions_visits.groupby('platform').count().orderBy('count', ascending=False).head(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>platform</th><th>count</th></tr></thead><tbody><tr><td>ANDROID</td><td>262643</td></tr><tr><td>IOS</td><td>200977</td></tr></tbody></table></div>

# %% [markdown]
# # Campo: device_manufacturer
# _70 valores distintos (99 % nas 10 primeiras)_

# %%
# 70 Maioria entre apple, samsung, motorola, Xiaomi, [juntar como outros]
display(df_sessions_visits.groupby('device_manufacturer').count().orderBy('count', ascending=False).head(6))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_manufacturer</th><th>count</th></tr></thead><tbody><tr><td>Apple</td><td>200977</td></tr><tr><td>samsung</td><td>135191</td></tr><tr><td>motorola</td><td>73582</td></tr><tr><td>Xiaomi</td><td>22817</td></tr><tr><td>asus</td><td>13361</td></tr><tr><td>LGE</td><td>8958</td></tr></tbody></table></div>

# %% [markdown]
# # Campo: device_model
# _810 valores distintos_
#
# _(50% dos registros em 20 categorias)_
#
# _(73% dos registros em 50 categorias)_
#
# _Muitos valores distintos e com grande dispersão_
#
# _Avaliar se vale a pena reprocessar e agrupar as categorias (Ex. [iPhone9,1], [iPhone9,2], [iPhone9,3], [iPhone9,4])_

# %%
# OS 20/810 maiores tem 50 % (juntar os modelos)
display(df_sessions_visits.groupby('device_model').count().orderBy('count', ascending=False).head(20))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_model</th><th>count</th></tr></thead><tbody><tr><td>iPhone9,3</td><td>30041</td></tr><tr><td>iPhone8,1</td><td>23018</td></tr><tr><td>iPhone10,4</td><td>17924</td></tr><tr><td>iPhone9,4</td><td>17427</td></tr><tr><td>iPhone10,5</td><td>16873</td></tr><tr><td>iPhone11,8</td><td>13972</td></tr><tr><td>iPhone10,6</td><td>12425</td></tr><tr><td>iPhone7,2</td><td>11318</td></tr><tr><td>SM-G610M</td><td>10319</td></tr><tr><td>iPhone11,6</td><td>8842</td></tr><tr><td>SM-G950F</td><td>8560</td></tr><tr><td>iPhone11,2</td><td>8165</td></tr><tr><td>SM-G9600</td><td>7815</td></tr><tr><td>SM-G570M</td><td>7279</td></tr><tr><td>moto g(6) play</td><td>7138</td></tr><tr><td>SM-J810M</td><td>6403</td></tr><tr><td>iPhone8,4</td><td>6281</td></tr><tr><td>Moto G (5S)</td><td>5782</td></tr><tr><td>Moto G (5S) Plus</td><td>5715</td></tr><tr><td>Moto G (5)</td><td>5644</td></tr></tbody></table></div>

# %% [markdown]
# # Campo: media_network
# _Muitos valores nulls (98%)_

# %%
# Muitos valores nulls 453445 / 463620 (98%)
display(
  df_sessions_visits.where(
    'media_network is not null'
  ).groupby(
    'media_network'
  ).count().orderBy(
    'count', ascending=False
  ).head(6)
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>media_network</th><th>count</th></tr></thead><tbody><tr><td>googleadwords_int</td><td>4127</td></tr><tr><td>Email Avaliacao</td><td>3111</td></tr><tr><td>Facebook Ads</td><td>1075</td></tr><tr><td>twitter</td><td>795</td></tr><tr><td>MGM</td><td>473</td></tr><tr><td>criteo_int</td><td>103</td></tr></tbody></table></div>

# %% [markdown]
# # Campo: first_order_origin_feature
# _406 valores distintos (87% nas 20 maiores categorias)_

# %%
# Os 20/406 possuem 87%
display(df_sessions_visits.groupby('first_order_origin_feature').count().orderBy('count', ascending=False).head(7))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_order_origin_feature</th><th>count</th></tr></thead><tbody><tr><td>Featured Restaurant</td><td>122435</td></tr><tr><td>Last Restaurants</td><td>71207</td></tr><tr><td>Ranking</td><td>67407</td></tr><tr><td>Filter</td><td>20137</td></tr><tr><td>Lanches</td><td>18182</td></tr><tr><td>Pizza</td><td>15115</td></tr><tr><td>CRM Restaurant</td><td>12636</td></tr></tbody></table></div>

# %% [markdown]
# # Variávies Quantitativas
#
# ### timestamp
#
# - session_started_at_amsp
# - session_ended_at_amsp
# - session_started_at_utc0
# - session_ended_at_utc0
#
# ### Inteiros
#
# - session_duration_seconds
# - sum_event_open
# - sum_view_restaurant_screen
# - sum_view_dish_screen
# - sum_click_add_item
# - sum_view_checkout
# - sum_callback_purchase
# - order_session_quantity

# %% [markdown]
# # Campos de timestamp
# _2077 Registros sem a marcação de final da sessão nos campos session_ended_at_amsp e session_ended_at_utc0_

# %%
print(
df_sessions_visits.where('session_started_at_amsp is null').count(),
df_sessions_visits.where('session_ended_at_amsp is null').count(),
df_sessions_visits.where('session_started_at_utc0 is null').count(),
df_sessions_visits.where('session_ended_at_utc0 is null').count()
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0 2077 0 2077
# </div>

# %% [markdown]
# #Abertura de sessão por dia da semana e hora

# %%
from pyspark.sql.functions import date_format, dayofweek, hour

display(
  df_sessions_visits.groupby(
    dayofweek('session_started_at_amsp').alias('dow'),
    date_format('session_started_at_amsp', 'E').alias('day'),
    hour('session_started_at_amsp').alias('hour')
  ).count().orderBy(['dow', 'hour'])
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th
2</td><td>96</td></tr><tr><td>3</td><td>Tue</td><td>3</td><td>39</td></tr><tr><td>3</td><td>Tue</td><td>4</td><td>11</td></tr><tr><td>3</td><td>Tue</td><td>5</td><td>8</td></tr><tr><td>3</td><td>Tue</td><td>6</td><td>21</td></tr><tr><td>3</td><td>Tue</td><td>7</td><td>70</td></tr><tr><td>3</td><td>Tue</td><td>8</td><td>155</td></tr><tr><td>3</td><td>Tue</td><td>9</td><td>350</td></tr><tr><td>3</td><td>Tue</td><td>10</td><td>1504</td></tr><tr><td>3</td><td>Tue</td><td>11</td><td>6361</td></tr><tr><td>3</td><td>Tue</td><td>12</td><td>5612</td></tr><tr><td>3</td><td>Tue</td><td>13</td><td>3292</td></tr><tr><td>3</td><td>Tue</td><td>14</td><td>2007</td></tr><tr><td>3</td><td>Tue</td><td>15</td><td>1844</td></tr><tr><td>3</td><td>Tue</td><td>16</td><td>1518</td></tr><tr><td>3</td><td>Tue</td><td>17</td><td>1598</td></tr><tr><td>3</td><td>Tue</td><td>18</td><td>4967</td></tr><tr><td>3</td><td>Tue</td><td>19</td><td>7156</td></tr><tr><td>3</td><td>Tue</td><td>20</td><td>6773</td></tr><tr><td>3</td><td>Tue</td><td>21</td><td>5432</td></tr><tr><td>3</td><td>Tue</td><td>22</td><t ...

# %% [markdown]
# # Campo: session_duration_seconds
# _11018 outlier (valores muito altos)_
#
# _13 valores negativo (não faz sentido)_
#
# _1150 valores para mas de 6 horas de sessão_

# %%
df_sessions_visits.where('session_duration_seconds > (60 * 60 * 6)') .count(), df_sessions_visits.where('session_duration_seconds < 0') .count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[62]: (1150, 13)</div>

# %%
display(df_sessions_visits.select('session_duration_seconds').summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>session_duration_seconds</th></tr></thead><tbody><tr><td>count</td><td>461543</td></tr><tr><td>mean</td><td>2658.8750712284664</td></tr><tr><td>stddev</td><td>20585.254195389633</td></tr><tr><td>min</td><td>-93.0</td></tr><tr><td>25%</td><td>667.0</td></tr><tr><td>50%</td><td>1792.0</td></tr><tr><td>75%</td><td>3152.0</td></tr><tr><td>max</td><td>2575751.0</td></tr></tbody></table></div>

# %%
# Verificar outliers (valores negativos e muito altos)
display(
  df_sessions_visits.select(
    'session_duration_seconds'
  ).where('session_duration_seconds < (24 * 60 * 60 * 6)').groupby(
    'session_duration_seconds'
  ).count().orderBy(
    'session_duration_seconds', ascending=False
  )
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3188798736452968&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-red-fg"># Verificar outliers (valores negativos e muito altos)</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span> display(
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg">   df_sessions_visits.select(
# </span><span class="ansi-green-intense-fg ansi-bold">      4</span>     <span class="ansi-blue-fg">&#39;session_duration_seconds&#39;</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span>   <span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>where<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;session_duration_seconds &lt; (24 * 60 * 60 * 6)&#39;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>groupby<span class="ansi-blue-fg">(</span>
#
# <span class="ansi-red-fg">NameError</span>: name &#39;df_sessions_visits&#39; is not defined</div>

# %%
df_sessions_visits.where('session_duration_seconds > 1000000').limit(3).toPandas().transpose()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>session_id</th>
#       <td>a3a57dfe-0c34-4e32-8d32-5c61958f2d3b</td>
#       <td>a7cbe85c-e4e8-459b-9538-d651953def66</td>
#       <td>48b976bd-1537-4e10-a923-8b7eda443c7e</td>
#     </tr>
#     <tr>
#       <th>dau</th>
#       <td>2019-12-07_003eacec-005e-4c5c-80ff-b7ffe0467d14</td>
#       <td>2019-08-22_50a96df6-554d-49d7-99fb-ad39d60e178e</td>
#       <td>2019-06-29_7bf1d02b-6f26-48ac-bf53-11cbf94a67a8</td>
#     </tr>
#     <tr>
#       <th>platform</th>
#       <td>ANDROID</td>
#       <td>ANDROID</td>
#       <td>ANDROID</td>
#     </tr>
#     <tr>
#       <th>user_identifier</th>
#       <td>d66b053d0c4d35a8c061089396175275928340f44abd4b...</td>
#       <td>2115dc8d454458c94ed8a663cb08c1b3c29b978a86d75f...</td>
#       <td>013d5458-0ef3-49ef-8ddc-3bc90526bac9</td>
#     </tr>
#     <tr>
#       <th>user_account_uuid</th>
#       <td>1bf907dc-0f6f-457e-af6c-3c0c828888dc</td>
#       <td>e74c78ff2079c716479b0429e50f378d37e24ad3a494a9...</td>
#       <td>013d5458-0ef3-49ef-8ddc-3bc90526bac9</td>
#     </tr>
#     <tr>
#       <th>session_started_at_amsp</th>
#       <td>2019-12-07T20:33:48.690Z</td>
#       <td>2019-08-22T17:34:04.004Z</td>
#       <td>2019-06-29T19:01:40.040Z</td>
#     </tr>
#     <tr>
#       <th>session_ended_at_amsp</th>
#       <td>2019-12-28T20:34:05.575Z</td>
#       <td>2019-09-05T16:27:37.627Z</td>
#       <td>2019-07-20T15:17:28.374Z</td>
#     </tr>
#     <tr>
#       <th>session_started_at_utc0</th>
#       <td>2019-12-07T22:33:48.690Z</td>
#       <td>2019-08-22T20:34:04.004Z</td>
#       <td>2019-06-29T22:01:40.040Z</td>
#     </tr>
#     <tr>
#       <th>session_ended_at_utc0</th>
#       <td>2019-12-28T22:34:05.575Z</td>
#       <td>2019-09-05T19:27:37.627Z</td>
#       <td>2019-07-20T18:17:28.374Z</td>
#     </tr>
#     <tr>
#       <th>session_duration_seconds</th>
#       <td>1.814e+06</td>
#       <td>1.206e+06</td>
#       <td>1.801e+06</td>
#     </tr>
#     <tr>
#       <th>device_model</th>
#       <td>SM-J730G</td>
#       <td>ANE-LX3</td>
#       <td>Moto G (4)</td>
#     </tr>
#     <tr>
#       <th>device_manufacturer</th>
#       <td>samsung</td>
#       <td>HUAWEI</td>
#       <td>motorola</td>
#     </tr>
#     <tr>
#       <th>sum_event_open</th>
#       <td>11</td>
#       <td>1</td>
#       <td>9</td>
#     </tr>
#     <tr>
#       <th>sum_view_restaurant_screen</th>
#       <td>9</td>
#       <td>10</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>sum_view_dish_screen</th>
#       <td>9</td>
#       <td>11</td>
#       <td>21</td>
#     </tr>
#     <tr>
#       <th>sum_click_add_item</th>
#       <td>4</td>
#       <td>3</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>sum_view_checkout</th>
#       <td>10</td>
#       <td>4</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>sum_callback_purchase</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>order_session_quantity</th>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>first_order_origin_feature</th>
#       <td>Mexicana</td>
#       <td>Last Restaurants</td>
#       <td>Featured Restaurant</td>
#     </tr>
#     <tr>
#       <th>media_network</th>
#       <td>googleadwords_int</td>
#       <td>Facebook Ads</td>
#       <td>twitter</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Campo: sum_event_open
# _128 valores null (??)_
#
# _7 valores zerados_
#
# _97% abaixo de 20 eventos_

# %% [markdown]
# # Campo: sum_view_restaurant_screen
#
# _15264 valores nulos_
#
# _1828 valores zerados_
#
# _87% até 20 eventos_

# %% [markdown]
# # Campo: sum_view_dish_screen
#
# _5730 valores nulos_
#
# _714 valores zerados_
#
# _95% até 20 eventos_

# %% [markdown]
# # Campo: sum_click_add_item
#
# _7069 valores nulos_
#
# _890 valores zerados_
#
# _98% até 20 eventos_

# %% [markdown]
# d
#  # Campo: sum_view_checkout
#  _1925 valores nulos_
#
#  _0 valores zerados_
#
#  _98% até 20 eventos_

# %% [markdown]
# # Distribuição dos eventos nas sessões

# %%
from pyspark.sql.functions import lit

lista = {
    'sum_event_open': 'open',
    'sum_view_restaurant_screen': 'view restaurant',
    'sum_view_dish_screen': 'view dish',
    'sum_click_add_item': 'click add',
    'sum_view_checkout': 'checkout'
}

final = None

for item, label in lista.items():
  print(item)
  dataset = df_sessions_visits.select(item).where(df_sessions_visits[item] > 0).groupby(item).count().orderBy(item).limit(20)
  dataset = dataset.withColumn("tabela", lit(label))
  dataset = dataset.withColumnRenamed(item, 'eventos por sessão')
  dataset = dataset.withColumnRenamed('count', 'total de sessões')
  
  if final is None:
    final = dataset
  else:
    final = final.unionAll(dataset)

display(final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>eventos por sessão</th><th>total de sessões</th><th>tabela</th></tr></thead><tbody><tr><td>1.0</td><td>62400</td><td>open</td></tr><tr><td>2.0</td><td>68356</td><td>open</td></tr><tr><td>3.0</td><td>58757</td><td>open</td></tr><tr><td>4.0</td><td>49342</td><td>open</td></tr><tr><td>5.0</td><td>40024</td><td>open</td></tr><tr><td>6.0</td><td>33117</td><td>open</td></tr><tr><td>7.0</td><td>27057</td><td>open</td></tr><tr><td>8.0</td><td>22074</td><td>open</td></tr><tr><td>9.0</td><td>17720</td><td>open</td></tr><tr><td>10.0</td><td>14475</td><td>open</td></tr><tr><td>11.0</td><td>11684</td><td>open</td></tr><tr><td>12.0</td><td>9712</td><td>open</td></tr><tr><td>13.0</td><td>7935</td><td>open</td></tr><tr><td>14.0</td><td>6494</td><td>open</td></tr><tr><td>15.0</td><td>5440</td><td>open</td></tr><tr><td>16.0</td><td>4525</td><td>open</td></tr><tr><td>17.0</td><td>3642</td><td>open</td></tr><tr><td>18.0</td><td>3094</td><td>open</td></tr><tr><td>19.0</td><td>2525</td><td>open</td></tr><tr><td>20.0</td><td>2081</td><td>open</td></tr><tr><td>1.0</td><td>81313</td><td>view restaurant</td></tr><tr><td>2.0</td><td>47427</td><td>view restaurant</td></tr><tr><td>3.0</td><td>43773</td><td>view restaurant</td></tr><tr><td>4.0</td><td>35852</td><td>view restaurant</td></tr><tr><td>5.0</td><td>28739</td><td>view restaurant</td></tr><tr><td>6.0</td><td>27258</td><td>view restaurant</td></tr><tr><td>7.0</td><td>19510</td><td>view restaurant</td></tr><tr><td>8.0</td><td>19983</td><td>view restaurant</td></tr><tr><td>9.0</td><td>13987</td><td>view restaurant</td></tr><tr><td>10.0</td><td>15217</td><td>view restaurant</td></tr><tr><td>11.0</td><td>10242</td><td>view restaurant</td></tr><tr><td>12.0</td><td>11557</td><td>view restaurant</td></tr><tr><td>13.0</td><td>7602</td><td>view restaurant</td></tr><tr><td>14.0</td><td>8854</td><td>view restaurant</td></tr><tr><td>15.0</td><td>5714</td><td>view restaurant</td></tr><tr><td>16.0</td><td>7161</td><td>view restaurant</td></tr><tr><td>17.0</td><td>4396</td><td>view restaurant</td></tr><tr><td>18.0</td><td>5567</td><td>view restaurant</td></tr><tr><td>19.0</td><td>3448</td><td>view restaurant</td></tr><tr><td>20.0</td><td>4587</td><td>view restaurant</td></tr><tr><td>1.0</td><td>78045</td><td>view dish</td></tr><tr><td>2.0</td><td>77606</td><td>view dish</td></tr><tr><td>3.0</td><td>61545</td><td>view dish</td></tr><tr><td>4.0</td><td>48256</td><td>view dish</td></tr><tr><td>5.0</td><td>36790</td><td>view dish</td></tr><tr><td>6.0</td><td>28863</td><td>view dish</td></tr><tr><td>7.0</td><td>22249</td><td>view dish</td></tr><tr><td>8.0</td><td>17807</td><td>view dish</td></tr><tr><td>9.0</td><td>14080</td><td>view dish</td></tr><tr><td>10.0</td><td>11439</td><td>view dish</td></tr><tr><td>11.0</td><td>9184</td><td>view dish</td></tr><tr><td>12.0</td><td>7523</td><td>view dish</td></tr><tr><td>13.0</td><td>6120</td><td>view dish</td></tr><tr><td>14.0</td><td>5184</td><td>view dish</td></tr><tr><td>15.0</td><td>4280</td><td>view dish</td></tr><tr><td>16.0</td><td>3775</td><td>view dish</td></tr><tr><td>17.0</td><td>3030</td><td>view dish</td></tr><tr><td>18.0</td><td>2528</td><td>view dish</td></tr><tr><td>19.0</td><td>2191</td><td>view dish</td></tr><tr><td>20.0</td><td>1890</td><td>view dish</td></tr><tr><td>1.0</td><td>157281</td><td>click add</td></tr><tr><td>2.0</td><td>117622</td><td>click add</td></tr><tr><td>3.0</td><td>65202</td><td>click add</td></tr><tr><td>4.0</td><td>40986</td><td>click add</td></tr><tr><td>5.0</td><td>23955</td><td>click add</td></tr><tr><td>6.0</td><td>15884</td><td>click add</td></tr><tr><td>7.0</td><td>9816</td><td>click add</td></tr><tr><td>8.0</td><td>7011</td><td>click add</td></tr><tr><td>9.0</td><td>4510</td><td>click add</td></tr><tr><td>10.0</td><td>3289</td><td>click add</td></tr><tr><td>11.0</td><td>2247</td><td>click add</td></tr><tr><td>12 ...

# %% [markdown]
# #Campo: sum_callback_purchase
#
# _1352 valores nulos_
#
# _211 valores zerados_

# %% [markdown]
# # Campo: order_session_quantity
#
# _1773 valores nulos_
#
# _368 valores zerados_

# %%
from pyspark.sql.functions import lit

lista = {
    'sum_callback_purchase': 'purchase',
    'order_session_quantity': 'order'
}

final = None

for item, label in lista.items():
  print(item)
  dataset = df_sessions_visits.select(item).where(df_sessions_visits[item] > 0)
  dataset = dataset.groupby(item).count().orderBy(item).limit(5)
  dataset = dataset.withColumn("tabela", lit(label))
  dataset = dataset.withColumnRenamed(item, 'eventos por sessão')
  dataset = dataset.withColumnRenamed('count', 'total de sessões')
  
  if final is None:
    final = dataset
  else:
    final = final.unionAll(dataset)

display(final)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>eventos por sessão</th><th>total de sessões</th><th>tabela</th></tr></thead><tbody><tr><td>1.0</td><td>409213</td><td>purchase</td></tr><tr><td>2.0</td><td>35459</td><td>purchase</td></tr><tr><td>3.0</td><td>8949</td><td>purchase</td></tr><tr><td>4.0</td><td>3429</td><td>purchase</td></tr><tr><td>5.0</td><td>1767</td><td>purchase</td></tr><tr><td>1.0</td><td>422286</td><td>order</td></tr><tr><td>2.0</td><td>31898</td><td>order</td></tr><tr><td>3.0</td><td>5014</td><td>order</td></tr><tr><td>4.0</td><td>1183</td><td>order</td></tr><tr><td>5.0</td><td>322</td><td>order</td></tr></tbody></table></div>

# %%
dfZero = summaryZeroNull(
  df_sessions_visits,
  [
    'sum_event_open',
    'sum_view_restaurant_screen',
    'sum_view_dish_screen',
    'sum_click_add_item',
    'sum_view_checkout',
    'sum_callback_purchase',
    'order_session_quantity'
  ]
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfSummary = df_sessions_visits[[
  'sum_event_open',
  'sum_view_restaurant_screen',
  'sum_view_dish_screen',
  'sum_click_add_item',
  'sum_view_checkout',
  'sum_callback_purchase',
  'order_session_quantity'
]].summary().toPandas().transpose(copy=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfFinal = dfSummary.copy()
dfFinal = dfFinal.reset_index()
dfFinal.columns = dfFinal.iloc[0,:].values
dfFinal.drop(index=[0], inplace=True)
dfFinal = dfFinal.astype({
  'mean':'float32', 'stddev':'float32',
  'min':'float32', '25%':'float32', '50%':'float32', '75%':'float32', 'max':'float32'
})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dfResumo = dfZero.merge(dfFinal)
dfResumo
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>summary</th>
#       <th>null</th>
#       <th>zero</th>
#       <th>count</th>
#       <th>mean</th>
#       <th>stddev</th>
#       <th>min</th>
#       <th>25%</th>
#       <th>50%</th>
#       <th>75%</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>sum_event_open</td>
#       <td>128</td>
#       <td>7</td>
#       <td>463492</td>
#       <td>6.0916</td>
#       <td>6.2486</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>8.0</td>
#       <td>631.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>sum_view_restaurant_screen</td>
#       <td>15264</td>
#       <td>1828</td>
#       <td>448356</td>
#       <td>8.9338</td>
#       <td>13.5800</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>5.0</td>
#       <td>11.0</td>
#       <td>1086.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>sum_view_dish_screen</td>
#       <td>5730</td>
#       <td>714</td>
#       <td>457890</td>
#       <td>5.7182</td>
#       <td>6.8103</td>
#       <td>0.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>7.0</td>
#       <td>409.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>sum_click_add_item</td>
#       <td>7069</td>
#       <td>890</td>
#       <td>456551</td>
#       <td>2.9305</td>
#       <td>3.9398</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>2.0</td>
#       <td>4.0</td>
#       <td>708.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>sum_view_checkout</td>
#       <td>1925</td>
#       <td>0</td>
#       <td>461695</td>
#       <td>4.2081</td>
#       <td>6.5453</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>3.0</td>
#       <td>5.0</td>
#       <td>800.0</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>sum_callback_purchase</td>
#       <td>1352</td>
#       <td>211</td>
#       <td>462268</td>
#       <td>1.2486</td>
#       <td>2.2442</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>359.0</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>order_session_quantity</td>
#       <td>1773</td>
#       <td>368</td>
#       <td>461847</td>
#       <td>1.1534</td>
#       <td>2.0747</td>
#       <td>0.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>1.0</td>
#       <td>311.0</td>
#     </tr>
#   </tbody>
# </table>
# </div>
